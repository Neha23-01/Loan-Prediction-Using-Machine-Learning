# %% [markdown]
# ## Import library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Read train file

# %%
df= pd.read_csv("C:\\Users\\user\\Desktop\\trainloan.csv")
df.head()
# Out:
#   Loan ID           NAME GENDER  DEPENDANTS MARRIED GRADUATE SELF-EMPLOYED  \
# 0   L0001           RITU      F           0       N        Y             Y
# 1   L0002          PINKY      F           0       N        Y             N
# 2   L0003  NEHA KRORIWAL      F           0       N        Y             N
# 3   L0004   RITU KHATKAR      F           0       N        Y             N
# 4   L0005         PREETI      F           2       N        Y             N
#
#    INCOME  LOAN AMOUNT  CREDIT-HISTORY PROPERTY-AREA
# 0    3000        50000               1         URBAN
# 1    3000        50000               1         URBAN
# 2    3000        50000               1         URBAN
# 3    3000        25000               1         URBAN
# 4    3000        30000               0         URBAN

# %% [markdown]
# ## Drop un-necessary column

# %%
df.drop('NAME',axis=1, inplace=True)
df.head()
# Out:
#   Loan ID GENDER  DEPENDANTS MARRIED GRADUATE SELF-EMPLOYED  INCOME  \
# 0   L0001      F           0       N        Y             Y    3000
# 1   L0002      F           0       N        Y             N    3000
# 2   L0003      F           0       N        Y             N    3000
# 3   L0004      F           0       N        Y             N    3000
# 4   L0005      F           2       N        Y             N    3000
#
#    LOAN AMOUNT  CREDIT-HISTORY PROPERTY-AREA
# 0        50000               1         URBAN
# 1        50000               1         URBAN
# 2        50000               1         URBAN
# 3        25000               1         URBAN
# 4        30000               0         URBAN

# %%
df.drop('Loan ID',axis=1, inplace=True)
df.head()
# Out:
#   GENDER  DEPENDANTS MARRIED GRADUATE SELF-EMPLOYED  INCOME  LOAN AMOUNT  \
# 0      F           0       N        Y             Y    3000        50000
# 1      F           0       N        Y             N    3000        50000
# 2      F           0       N        Y             N    3000        50000
# 3      F           0       N        Y             N    3000        25000
# 4      F           2       N        Y             N    3000        30000
#
#    CREDIT-HISTORY PROPERTY-AREA
# 0               1         URBAN
# 1               1         URBAN
# 2               1         URBAN
# 3               1         URBAN
# 4               0         URBAN

# %% [markdown]
# ## Shape of the file

# %%
df.shape
# Out:
# (100, 9)

# %% [markdown]
# ## Set dummy

# %%
dummy=pd.get_dummies(df['GENDER'])
dummy
# Out:
#     F  M
# 0   1  0
# 1   1  0
# 2   1  0
# 3   1  0
# 4   1  0
# .. .. ..
# 95  1  0
# 96  0  1
# 97  0  1
# 98  0  1
# 99  0  1
#
# [100 rows x 2 columns]

# %%
df=pd.concat((df,dummy),axis=1)
df
# Out:
#    GENDER  DEPENDANTS MARRIED GRADUATE SELF-EMPLOYED  INCOME  LOAN AMOUNT  \
# 0       F           0       N        Y             Y    3000        50000
# 1       F           0       N        Y             N    3000        50000
# 2       F           0       N        Y             N    3000        50000
# 3       F           0       N        Y             N    3000        25000
# 4       F           2       N        Y             N    3000        30000
# ..    ...         ...     ...      ...           ...     ...          ...
# 95      F           0       Y        Y             Y  200000        30000
# 96      M           0       Y        Y             Y   30000        50000
# 97      M           1       Y        Y             Y   15000        35000
# 98      M           2       Y        Y             Y   12000        35000
# 99      M           3       Y        Y             Y  120000        35000
#
#     CREDIT-HISTORY PROPERTY-AREA  F  M
# 0                1         URBAN  1  0
# ...

# %%
dummy=pd.get_dummies(df['MARRIED'])
dummy
# Out:
#     N  Y
# 0   1  0
# 1   1  0
# 2   1  0
# 3   1  0
# 4   1  0
# .. .. ..
# 95  0  1
# 96  0  1
# 97  0  1
# 98  0  1
# 99  0  1
#
# [100 rows x 2 columns]

# %%
df=pd.concat((df,dummy),axis=1)
df
# Out:
#    GENDER  DEPENDANTS MARRIED GRADUATE SELF-EMPLOYED  INCOME  LOAN AMOUNT  \
# 0       F           0       N        Y             Y    3000        50000
# 1       F           0       N        Y             N    3000        50000
# 2       F           0       N        Y             N    3000        50000
# 3       F           0       N        Y             N    3000        25000
# 4       F           2       N        Y             N    3000        30000
# ..    ...         ...     ...      ...           ...     ...          ...
# 95      F           0       Y        Y             Y  200000        30000
# 96      M           0       Y        Y             Y   30000        50000
# 97      M           1       Y        Y             Y   15000        35000
# 98      M           2       Y        Y             Y   12000        35000
# 99      M           3       Y        Y             Y  120000        35000
#
#     CREDIT-HISTORY PROPERTY-AREA  F  M  N  Y
# ...

# %% [markdown]
# ## Describe

# %%
df.describe()
# Out:
#        DEPENDANTS        INCOME    LOAN AMOUNT  CREDIT-HISTORY           F  \
# count  100.000000  1.000000e+02     100.000000      100.000000  100.000000
# mean     1.280000  2.853300e+04   70897.000000        0.840000    0.680000
# std      1.303298  1.305396e+05   70985.588885        0.368453    0.468826
# min      0.000000  2.000000e+03   15000.000000        0.000000    0.000000
# 25%      0.000000  3.000000e+03   35000.000000        1.000000    0.000000
# 50%      1.000000  3.000000e+03   35000.000000        1.000000    1.000000
# 75%      2.000000  1.200000e+04   78500.000000        1.000000    1.000000
# max      5.000000  1.200000e+06  350000.000000        1.000000    1.000000
#
#                 M          N          Y
# count  100.000000  100.00000  100.00000
# mean     0.320000    0.57000    0.43000
# std      0.468826    0.49757    0.49757
# min      0.000000    0.00000    0.00000
# 25%      0.000000    0.00000    0.00000
# 50%      0.000000    1.00000    0.00000
# ...

# %% [markdown]
# ## Graph-Plot for separate column

# %%
sns.distplot(df.INCOME,kde=False)

# %%
sns.boxplot(x='GRADUATE',y='INCOME',data=df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GENDER          100 non-null    object
#  1   DEPENDANTS      100 non-null    int64
#  2   MARRIED         100 non-null    object
#  3   GRADUATE        100 non-null    object
#  4   SELF-EMPLOYED   100 non-null    object
#  5   INCOME          100 non-null    int64
#  6   LOAN AMOUNT     100 non-null    int64
#  7   CREDIT-HISTORY  100 non-null    int64
#  8   PROPERTY-AREA   100 non-null    object
#  9   F               100 non-null    uint8
#  10  M               100 non-null    uint8
#  11  N               100 non-null    uint8
#  12  Y               100 non-null    uint8
# dtypes: int64(4), object(5), uint8(4)
# memory usage: 7.5+ KB

# %%
df.isnull().sum()
# Out:
# GENDER            0
# DEPENDANTS        0
# MARRIED           0
# GRADUATE          0
# SELF-EMPLOYED     0
# INCOME            0
# LOAN AMOUNT       0
# CREDIT-HISTORY    0
# PROPERTY-AREA     0
# F                 0
# M                 0
# N                 0
# Y                 0
# dtype: int64

# %%
sns.countplot(df['GENDER'])

# %%
sns.countplot(df['MARRIED'])

# %%
sns.countplot(df['DEPENDANTS'])

# %%
sns.countplot(df['SELF-EMPLOYED'])

# %%
sns.countplot(df['PROPERTY-AREA'])

# %% [markdown]
# ## Read test file

# %%
df2= pd.read_csv("C:\\Users\\user\\Desktop\\testloan.csv")
df2.head()
# Out:
#   Loan ID           NAME GENDER  DEPENDANTS MARRIED GRADUATE SELF-EMPLOYED  \
# 0   L0001           RITU      F           0       N        Y             Y
# 1   L0002          PINKY      F           0       N        Y             N
# 2   L0003  NEHA KRORIWAL      F           0       N        Y             N
# 3   L0004   RITU KHATKAR      F           0       N        Y             N
# 4   L0005         PREETI      F           2       N        Y             N
#
#    INCOME  LOAN AMOUNT  CREDIT-HISTORY PROPERTY-AREA LOAN-STATUS
# 0    3000        50000               1         URBAN           Y
# 1    3000        50000               1         URBAN           Y
# 2    3000        50000               1         URBAN           Y
# 3    3000        25000               1         URBAN           Y
# 4    3000        30000               0         URBAN           N

# %%
sns.countplot(df2['LOAN-STATUS'])

# %%
df['INCOME']=np.log(df['INCOME'])
sns.distplot(df['INCOME'])

# %%
sns.distplot(df['LOAN AMOUNT'])

# %%
df['LOAN AMOUNT']=np.log(df['LOAN AMOUNT'])
sns.distplot(df['LOAN AMOUNT'])

# %%
sns.distplot(df['CREDIT-HISTORY'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-77-0d4dcddc7358> in <module>
# ----> 1 sns.distplot(df['CREDIT-HISTORY'])
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     231     if kde:
#     232         kde_color = kde_kws.pop("color", color)
# ...

# %%
df.head()
# Out:
#   GENDER  DEPENDANTS MARRIED GRADUATE SELF-EMPLOYED    INCOME  LOAN AMOUNT  \
# 0      F           0       N        Y             Y  8.006368    10.819778
# 1      F           0       N        Y             N  8.006368    10.819778
# 2      F           0       N        Y             N  8.006368    10.819778
# 3      F           0       N        Y             N  8.006368    10.126631
# 4      F           2       N        Y             N  8.006368    10.308953
#
#    CREDIT-HISTORY PROPERTY-AREA  F  M  N  Y
# 0               1         URBAN  1  0  1  0
# 1               1         URBAN  1  0  1  0
# 2               1         URBAN  1  0  1  0
# 3               1         URBAN  1  0  1  0
# 4               0         URBAN  1  0  1  0

# %% [markdown]
# ## Conversion of string value in binary for train file

# %%
from sklearn.preprocessing import LabelEncoder
cols=["GENDER","MARRIED","GRADUATE","SELF-EMPLOYED","PROPERTY-AREA"]
l=LabelEncoder()
for col in cols:
    df[col]=l.fit_transform(df[col])

# %%
df.head()
# Out:
#    GENDER  DEPENDANTS  MARRIED  GRADUATE  SELF-EMPLOYED    INCOME  \
# 0       0           0        0         1              1  8.006368
# 1       0           0        0         1              0  8.006368
# 2       0           0        0         1              0  8.006368
# 3       0           0        0         1              0  8.006368
# 4       0           2        0         1              0  8.006368
#
#    LOAN AMOUNT  CREDIT-HISTORY  PROPERTY-AREA  F  M  N  Y
# 0    10.819778               1              1  1  0  1  0
# 1    10.819778               1              1  1  0  1  0
# 2    10.819778               1              1  1  0  1  0
# 3    10.126631               1              1  1  0  1  0
# 4    10.308953               0              1  1  0  1  0

# %%
df2.head()
# Out:
#   Loan ID           NAME GENDER  DEPENDANTS MARRIED GRADUATE SELF-EMPLOYED  \
# 0   L0001           RITU      F           0       N        Y             Y
# 1   L0002          PINKY      F           0       N        Y             N
# 2   L0003  NEHA KRORIWAL      F           0       N        Y             N
# 3   L0004   RITU KHATKAR      F           0       N        Y             N
# 4   L0005         PREETI      F           2       N        Y             N
#
#    INCOME  LOAN AMOUNT  CREDIT-HISTORY PROPERTY-AREA LOAN-STATUS
# 0    3000        50000               1         URBAN           Y
# 1    3000        50000               1         URBAN           Y
# 2    3000        50000               1         URBAN           Y
# 3    3000        25000               1         URBAN           Y
# 4    3000        30000               0         URBAN           N

# %% [markdown]
# ## Drop column from test file

# %%
df2.drop('Loan ID',axis=1, inplace=True)
df2.head()
# Out:
#             NAME GENDER  DEPENDANTS MARRIED GRADUATE SELF-EMPLOYED  INCOME  \
# 0           RITU      F           0       N        Y             Y    3000
# 1          PINKY      F           0       N        Y             N    3000
# 2  NEHA KRORIWAL      F           0       N        Y             N    3000
# 3   RITU KHATKAR      F           0       N        Y             N    3000
# 4         PREETI      F           2       N        Y             N    3000
#
#    LOAN AMOUNT  CREDIT-HISTORY PROPERTY-AREA LOAN-STATUS
# 0        50000               1         URBAN           Y
# 1        50000               1         URBAN           Y
# 2        50000               1         URBAN           Y
# 3        25000               1         URBAN           Y
# 4        30000               0         URBAN           N

# %%
df2.drop('NAME',axis=1, inplace=True)
df2.head()
# Out:
#   GENDER  DEPENDANTS MARRIED GRADUATE SELF-EMPLOYED  INCOME  LOAN AMOUNT  \
# 0      F           0       N        Y             Y    3000        50000
# 1      F           0       N        Y             N    3000        50000
# 2      F           0       N        Y             N    3000        50000
# 3      F           0       N        Y             N    3000        25000
# 4      F           2       N        Y             N    3000        30000
#
#    CREDIT-HISTORY PROPERTY-AREA LOAN-STATUS
# 0               1         URBAN           Y
# 1               1         URBAN           Y
# 2               1         URBAN           Y
# 3               1         URBAN           Y
# 4               0         URBAN           N

# %% [markdown]
# ## Conversion of string to binary in test file

# %%
from sklearn.preprocessing import LabelEncoder
cols=["GENDER","MARRIED","GRADUATE","SELF-EMPLOYED","PROPERTY-AREA","LOAN-STATUS"]
l=LabelEncoder()
for col in cols:
    df2[col]=l.fit_transform(df2[col])

# %%
df2.head(50)
# Out:
#     GENDER  DEPENDANTS  MARRIED  GRADUATE  SELF-EMPLOYED  INCOME  LOAN AMOUNT  \
# 0        0           0        0         1              1    3000        50000
# 1        0           0        0         1              0    3000        50000
# 2        0           0        0         1              0    3000        50000
# 3        0           0        0         1              0    3000        25000
# 4        0           2        0         1              0    3000        30000
# 5        0           4        0         1              0    3000        40000
# 6        0           2        0         1              0    3000        45000
# 7        0           1        0         1              0    3000       100000
# 8        0           0        0         1              0    3000        30000
# 9        0           0        0         1              0    3000        50000
# 10       0           0        0         1              0    3000        32000
# ...

# %% [markdown]
# ## Model classification

# %%
x=df
y=df2['LOAN-STATUS']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.model_selection import cross_val_score
def classify(model, x, y):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)
    model.fit(x_train, y_train)
    print("Accuracy is", model.score(x_test, y_test)*100)
    score = cross_val_score(model, x, y, cv=5)
    print("cross validation is ,",np.mean(score)*100)

# %% [markdown]
# ## Algorithm

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model, x, y)
# Out:
# Accuracy is 56.00000000000001
# cross validation is , 60.0

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
classify(model, x, y)
# Out:
# Accuracy is 56.00000000000001
# cross validation is , 59.00000000000001
